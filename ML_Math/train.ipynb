# %%
import numpy as np 
import matplotlib.pyplot as plt

train = np.loadtxt(r"./click.csv", delimiter=",",skiprows=1)
train_x = train[:,0]
train_y = train[:,1]

plt.plot(train_x,train_y,"o")
plt.show()

# %%
theta0 = np.random.rand()
theta1 = np.random.rand()

# %%
def f(x):
    return theta0 + theta1*x

# %%
def E(x, y):
    return 0.5 * np.sum((y-f(x)) ** 2)

# %%
mu = train_x.mean()
sigma = train_x.std()
def standardize(x):
    return (x - mu)/sigma

# %%
train_z = standardize(train_x)

# %%
train_z
# Out:
# array([ 1.39433428,  1.11069026,  0.09554325, -1.59139223, -0.8449606 ,
#         0.93154667, -1.38239138, -1.74067856,  0.46875906,  0.73747445,
#        -0.11345761, -0.63595975, -0.36724436, -0.44188752,  0.3045441 ,
#         1.94669369,  0.25975821,  0.25975821, -1.23310505,  0.84197488])

# %%
plt.plot(train_z, train_y, 'o')
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt
# 参数初始化
theta0 = np.random.rand()
theta1 = np.random.rand()

# 预测函数
def f(x):
    return theta0 + theta1 * x

# 目标函数
def E(x, y):
    return 0.5 * np.sum((y - f(x)) ** 2)

# %%
ETA = 1e-3

diff = 1

count = 0

error = E(train_z, train_y)

while diff > 1e-2:
    tmp0 = theta0 - ETA * np.sum((f(train_z)-train_y))
    tmp1 = theta1 - ETA * np.sum((f(train_z)-train_y) * train_z)
    theta0 = tmp0
    theta1 = tmp1

    current_error = E(train_z, train_y)
    diff = error - current_error
    error = current_error

    count += 1
    log = "第{}次 ：theta0 = {:.3f}, theta1 = {:.3f}, 差值= {:.4f}"
    print(log.format(count, theta0, theta1, diff))
# Out:
# , 差值= 30043.7120
# 第23次 ：theta0 = 170.577, theta1 = 37.637, 差值= 28853.9810
# 第24次 ：theta0 = 175.749, theta1 = 38.754, 差值= 27711.3634
# 第25次 ：theta0 = 180.817, theta1 = 39.849, 差值= 26613.9934
# 第26次 ：theta0 = 185.783, theta1 = 40.921, 差值= 25560.0792
# 第27次 ：theta0 = 190.651, theta1 = 41.972, 差值= 24547.9001
# 第28次 ：theta0 = 195.421, theta1 = 43.003, 差值= 23575.8032
# 第29次 ：theta0 = 200.095, theta1 = 44.012, 差值= 22642.2014
# 第30次 ：theta0 = 204.676, theta1 = 45.001, 差值= 21745.5703
# 第31次 ：theta0 = 209.166, theta1 = 45.971, 差值= 20884.4457
# 第32次 ：theta0 = 213.565, theta1 = 46.921, 差值= 20057.4216
# 第33次 ：theta0 = 217.877, theta1 = 47.852, 差值= 19263.1477
# 第34次 ：theta0 = 222.103, theta1 = 48.765, 差值= 18500.3271
# 第35次 ：theta0 = 226.244, theta1 = 49.659, 差值= 17767.7141
# 第36次 ：theta0 = 230.302, theta1 = 50.535, 差值= 17064.1127
# 第37次 ：theta0 = 234.279, theta1 = 51.394, 差值= 16388.3738
# 第38次 ：theta0 = 238.176, theta1 = 52.236, 差值= 15739.3942
# 第39次 ：theta0 = 241.996, theta1 = 53.061, 差值= 15116.1142
# 第40次 ：theta0 = 245.739, theta1 = 53.869, 差值= 14517.5161
# 第41次 ：theta0 = 249.407, theta1 = 54.661, 差值= 13942.6224
# 第42次 ：theta0 = 253.002, theta1 = 55.438, 差值= 13390.4946
# 第43次 ：theta0 = 256.525, theta1 = 56.199, 差值= 12860.2310
# 第44次 ：theta0 = 259.977, theta1 = 56.944, 差值= 12350.9658
# 第45次 ：theta0 = 263.361, theta1 = 57.675, 差值= 11861.8676
# 第46次 ：theta0 = 266.676, theta1 = 58.391, 差值= 11392.1376
# 第47次 ：theta0 = 269.926, theta1 = 59.093, 差值= 10941.0090
# 第48次 ：theta0 = 273.110, theta1 = 59.780, 差值= 10507.7450
# 第49次 ：theta0 = 276.231, theta1 = 60.454, 差值= 10091.6383
# 第50次 ：theta0 = 279.290, theta1 = 61.115, 差值= 9692.0094
# 第51次 ：theta0 = 282.287, theta1 = 61.762, 差值= 9308.2059
# 第52次 ：theta0 = 285.224, theta1 = 62.396, 差值= 8939.6009
# 第53次 ：theta0 = 288.103, theta1 = 63.018, 差值= 8585.5927
# 第54次 ：theta0 = 290.924, theta1 = 63.627, 差值= 8245.6033
# 第55次 ：theta0 = 293.688, theta1 = 64.224, 差值= 7919.0774
# 第56次 ：theta0 = 296.397, theta1 = 64.809, 差值= 7605.4819
# 第57次 ：theta0 = 299.052, theta1 = 65.383, 差值= 7304.3048
# 第58次 ：theta0 = 301.654, theta1 = 65.945, 差值= 7015.0543
# 第59次 ：theta0 = 304.204, theta1 = 66.495, 差值= 6737.2582
# 第60次 ：theta0 = 306.703, theta1 = 67.035, 差值= 6470.4628
# 第61次 ：theta0 = 309.152, theta1 = 67.564, 差值= 6214.2324
# 第62次 ：theta0 = 311.552, theta1 = 68.082, 差值= 5968.1488
# 第63次 ：theta0 = 313.904, theta1 = 68.590, 差值= 5731.8101
# 第64次 ：theta0 = 316.209, theta1 = 69.088, 差值= 5504.8305
# 第65次 ：theta0 = 318.468, theta1 = 69.576, 差值= 5286.8392
# 第66次 ：theta0 = 320.681, theta1 = 70.054, 差值= 5077.4803
# 第67次 ：theta0 = 322.851, theta1 = 70.522, 差值= 4876.4121
# 第68次 ：theta0 = 324.977, theta1 = 70.981, 差值= 4683.3062
# 第69次 ：theta0 = 327.060, theta1 = 71.431, 差值= 4497.8473
# 第70次 ：theta0 = 329.102, theta1 = 71.872, 差值= 4319.7325
# 第71次 ：theta0 = 331.103, theta1 = 72.305, 差值= 4148.6711
# 第72次 ：theta0 = 333.064, theta1 = 72.728, 差值= 3984.3837
# 第73次 ：theta0 = 334.986, theta1 = 73.143, 差值= 3826.6021
# 第74次 ：theta0 = 336.869, theta1 = 73.550, 差值= 3675.0687
# 第75次 ：theta0 = 338.715, theta1 = 73.948, 差值= 3529.5360
# 第76次 ：theta0 = 340.523, theta1 = 74.339, 差值= 3389.7664
# 第77次 ：theta0 = 342.296, theta1 = 74.722, 差值= 3255.5316
# 第78次 ：theta0 = 344.033, theta1 = 75.097, 差值= 3126.6126
# 第79次 ：theta0 = 345.735, theta1 = 75.464, 差值= 3002.7987
# 第80次 ：theta0 = 347.403, theta1 = 75.825, 差值= 2883.8879
# 第81次 ：theta0 = 349.038, theta1 = 76.178, 差值= 2769.6859
# 第82次 ：theta0 = 350.641, theta1 = 76.524, 差值= 2660.0063
# 第83次 ：theta0 = 352.211, theta1 = 76.863, 差值= 2554.6701
# 第84次 ：theta0 = 353.750, theta1 = 77.195, 差值= 2453.5052
# 第85次 ：theta0 = 355.258, theta1 = 77.521, 差值= 2356.3464
# 第86次 ：theta0 = 356.735, theta1 = 77.840, 差值= 2263.0350
# 第87次 ：theta0 = 358.184, theta1 = 78.153, 差值= 2173.4189
# 第88次 ：theta0 = 359.603, theta1 = 78.459, 差值= 2087.3515
# 第89次 ：theta0 = 360.994, theta1 = 78.760, 差值= 2004.6923
# 第90次 ：theta0 = 362.357, theta1 = 79.054, 差值= 1925.3065
# 第91次 ：theta0 = 363.693, theta1 = 79.343, 差值= 1849.0644
# 第92次 ：theta0 = 365.002, theta1 = 79.625, 差值= 1775.8414
# 第93次 ：theta0 = 366.285, theta1 = 79.902, 差值= 1705.5181
# 第94次 ：theta0 = 367.542, theta1 = 80.174, 差值= 1637.9796
# 第95次 ：theta0 = 368.775, theta1 = 80.440, 差值= 1573.1156
# 第96次 ：theta0 = 369.982, theta1 = 80.701, 差值= 1510.8202
# 第97次 ：theta0 = 371.165, theta1 = 80.956, 差值= 1450.9918
# 第98次 ：theta0 = 372.325, theta1 = 81.207, 差值= 1393.5325
# 第99次 ：theta0 = 373.462, theta1 = 81.452, 差值= 1338.3486
# 第100次 ：theta0 = 374.575, theta1 = 81.693, 差值= 1285.3500
# 第101次 ：theta0 = 375.667, theta1 = 81.929, 差值= 1234.4501
# 第102次 ：theta0 = 376.737, theta1 = 82.160, 差值= 1185.5659
# 第103次 ：theta0 = 377.785, theta1 = 82.386, 差值= 1138.6175
# 第104次 ：theta0 = 378.812, theta1 = 82.608, 差值= 1093.5282
# 第105次 ：theta0 = 379.819, theta1 = 82.825, 差值= 1050.2245
# 第106次 ：theta0 = 380.805, theta1 = 83.038, 差值= 1008.6356
# 第107次 ：theta0 = 381.772, theta1 = 83.247, 差值= 968.6937
# 第108次 ：theta0 = 382.720, theta1 = 83.452, 差值= 930.3334
# 第109次 ：theta0 = 383.649, theta1 = 83.652, 差值= 893.4922
# 第110次 ：theta0 = 384.559, theta1 = 83.849, 差值= 858.1099
# 第111次 ：theta0 = 385.450, theta1 = 84.041, 差值= 824.1287
# 第112次 ：theta0 = 386.324, theta1 = 84.230, 差值= 791.4932
# 第113次 ：theta0 = 387.181, theta1 = 84.415, 差值= 760.1501
# 第114次 ：theta0 = 388.020, theta1 = 84.596, 差值= 730.0482
# 第115次 ：theta0 = 388.843, theta1 = 84.774, 差值= 701.1383
# 第116次 ：theta0 = 389.649, theta1 = 84.948, 差值= 673.3732
# 第117次 ：theta0 = 390.439, theta1 = 85.119, 差值= 646.7076
# 第118次 ：theta0 = 391.213, theta1 = 85.286, 差值= 621.0980
# 第119次 ：theta0 = 391.972, theta1 = 85.450, 差值= 596.5025
# 第120次 ：theta0 = 392.716, theta1 = 85.610, 差值= 572.8810
# 第121次 ：theta0 = 393.444, theta1 = 85.768, 差值= 550.1949
# 第122次 ：theta0 = 394.158, theta1 = 85.922, 差值= 528.4072
# 第123次 ：theta0 = 394.858, theta1 = 86.073, 差值= 507.4823
# 第124次 ：theta0 = 395.544, theta1 = 86.221, 差值= 487.3860
# 第125次 ：theta0 = 396.216, theta1 = 86.366, 差值= 468.0855
# 第126次 ：theta0 = 396.875, theta1 = 86.509, 差值= 449.5493
# 第127次 ：theta0 = 397.520, theta1 = 86.648, 差值= 431.7472
# 第128次 ：theta0 = 398.153, theta1 = 86.785, 差值= 414.6500
# 第129次 ：theta0 = 398.773, theta1 = 86.919, 差值= 398.2298
# 第130次 ：theta0 = 399.380, theta1 = 87.050, 差值= 382.4599
# 第131次 ：theta0 = 399.976, theta1 = 87.178, 差值= 367.3145
# 第132次 ：theta0 = 400.559, theta1 = 87.304, 差值= 352.7689
# 第133次 ：theta0 = 401.131, theta1 = 87.428, 差值= 338.7992
# 第134次 ：theta0 = 401.691, theta1 = 87.549, 差值= 325.3828
# 第135次 ：theta0 = 402.241, theta1 = 87.667, 差值= 312.4976
# 第136次 ：theta0 = 402.779, theta1 = 87.784, 差值= 300.1227
# 第137次 ：theta0 = 403.306, theta1 = 87.898, 差值= 288.2378
# 第138次 ：theta0 = 403.823, theta1 = 88.009, 差值= 276.8236
# 第139次 ：theta0 = 404.330, theta1 = 88.119, 差值= 265.8614
# 第140次 ：theta0 = 404.826, theta1 = 88.226, 差值= 255.3333
# 第141次 ：theta0 = 405.313, theta1 = 88.331, 差值= 245.2221
# 第142次 ：theta0 = 405.789, theta1 = 88.434, 差值= 235.5113
# 第143次 ：theta0 = 406.257, theta1 = 88.535, 差值= 226.1851
# 第144次 ：theta0 = 406.714, theta1 = 88.634, 差值= 217.2281
# 第145次 ：theta0 = 407.163, theta1 = 88.730, 差值= 208.6259
# 第146次 ：theta0 = 407.603, theta1 = 88.825, 差值= 200.3643
# 第147次 ：theta0 = 408.034, theta1 = 88.919, 差值= 192.4299
# 第148次 ：theta0 = 408.456, theta1 = 89.010, 差值= 184.8097
# 第149次 ：theta0 = 408.870, theta1 = 89.099, 差值= 177.4912
# 第150次 ：theta0 = 409.276, theta1 = 89.187, 差值= 170.4625
# 第151次 ：theta0 = 409.673, theta1 = 89.273, 差值= 163.7122
# 第152次 ：theta0 = 410.063, theta1 = 89.357, 差值= 157.2292
# 第153次 ：theta0 = 410.444, theta1 = 89.439, 差值= 151.0029
# 第154次 ：theta0 = 410.818, theta1 = 89.520, 差值= 145.0232
# 第155次 ：theta0 = 411.185, theta1 = 89.599, 差值= 139.2803
# 第156次 ：theta0 = 411.544, theta1 = 89.677, 差值= 133.7648
# 第157次 ：theta0 = 411.897, theta1 = 89.753, 差值= 128.4677
# 第158次 ：theta0 = 412.242, theta1 = 89.827, 差值= 123.3804
# 第159次 ：theta0 = 412.580, theta1 = 89.900, 差值= 118.4945
# 第160次 ：theta0 = 412.911, theta1 = 89.972, 差值= 113.8022
# 第161次 ：theta0 = 413.236, theta1 = 90.042, 差值= 109.2956
# 第162次 ：theta0 = 413.554, theta1 = 90.111, 差值= 104.9675
# 第163次 ：theta0 = 413.866, theta1 = 90.178, 差值= 100.8108
# 第164次 ：theta0 = 414.172, theta1 = 90.244, 差值= 96.8187
# 第165次 ：theta0 = 414.471, theta1 = 90.309, 差值= 92.9846
# 第166次 ：theta0 = 414.765, theta1 = 90.372, 差值= 89.3025
# 第167次 ：theta0 = 415.053, theta1 = 90.434, 差值= 85.7661
# 第168次 ：theta0 = 415.335, theta1 = 90.495, 差值= 82.3697
# 第169次 ：theta0 = 415.611, theta1 = 90.555, 差值= 79.1079
# 第170次 ：theta0 = 415.882, theta1 = 90.613, 差值= 75.9752
# 第171次 ：theta0 = 416.147, theta1 = 90.671, 差值= 72.9666
# 第172次 ：theta0 = 416.407, theta1 = 90.727, 差值= 70.0771
# 第173次 ：theta0 = 416.662, theta1 = 90.782, 差值= 67.3021
# 第174次 ：theta0 = 416.912, theta1 = 90.836, 差值= 64.6369
# 第175次 ：theta0 = 417.156, theta1 = 90.889, 差值= 62.0773
# 第176次 ：theta0 = 417.396, theta1 = 90.940, 差值= 59.6190
# 第177次 ：theta0 = 417.631, theta1 = 90.991, 差值= 57.2581
# 第178次 ：theta0 = 417.862, theta1 = 91.041, 差值= 54.9907
# 第179次 ：theta0 = 418.088, theta1 = 91.090, 差值= 52.8131
# 第180次 ：theta0 = 418.309, theta1 = 91.138, 差值= 50.7217
# 第181次 ：theta0 = 418.526, theta1 = 91.184, 差值= 48.7131
# 第182次 ：theta0 = 418.738, theta1 = 91.230, 差值= 46.7840
# 第183次 ：theta0 = 418.946, theta1 = 91.275, 差值= 44.9314
# 第184次 ：theta0 = 419.150, theta1 = 91.319, 差值= 43.1521
# 第185次 ：theta0 = 419.350, theta1 = 91.362, 差值= 41.4433
# 第186次 ：theta0 = 419.546, theta1 = 91.405, 差值= 39.8021
# 第187次 ：theta0 = 419.738, theta1 = 91.446, 差值= 38.2260
# 第188次 ：theta0 = 419.927, theta1 = 91.487, 差值= 36.7122
# 第189次 ：theta0 = 420.111, theta1 = 91.527, 差值= 35.2584
# 第190次 ：theta0 = 420.292, theta1 = 91.566, 差值= 33.8622
# 第191次 ：theta0 = 420.469, theta1 = 91.604, 差值= 32.5212
# 第192次 ：theta0 = 420.643, theta1 = 91.642, 差值= 31.2334
# 第193次 ：theta0 = 420.813, theta1 = 91.678, 差值= 29.9966
# 第194次 ：theta0 = 420.980, theta1 = 91.714, 差值= 28.8087
# 第195次 ：theta0 = 421.143, theta1 = 91.750, 差值= 27.6679
# 第196次 ：theta0 = 421.303, theta1 = 91.784, 差值= 26.5722
# 第197次 ：theta0 = 421.460, theta1 = 91.818, 差值= 25.5200
# 第198次 ：theta0 = 421.614, theta1 = 91.851, 差值= 24.5094
# 第199次 ：theta0 = 421.765, theta1 = 91.884, 差值= 23.5388
# 第200次 ：theta0 = 421.912, theta1 = 91.916, 差值= 22.6067
# 第201次 ：theta0 = 422.057, theta1 = 91.947, 差值= 21.7114
# 第202次 ：theta0 = 422.199, theta1 = 91.978, 差值= 20.8517
# 第203次 ：theta0 = 422.338, theta1 = 92.008, 差值= 20.0259
# 第204次 ：theta0 = 422.474, theta1 = 92.037, 差值= 19.2329
# 第205次 ：theta0 = 422.608, theta1 = 92.066, 差值= 18.4713
# 第206次 ：theta0 = 422.739, theta1 = 92.094, 差值= 17.7398
# 第207次 ：theta0 = 422.867, theta1 = 92.122, 差值= 17.0373
# 第208次 ：theta0 = 422.992, theta1 = 92.149, 差值= 16.3627
# 第209次 ：theta0 = 423.116, theta1 = 92.176, 差值= 15.7147
# 第210次 ：theta0 = 423.236, theta1 = 92.202, 差值= 15.0924
# 第211次 ：theta0 = 423.355, theta1 = 92.227, 差值= 14.4947
# 第212次 ：theta0 = 423.470, theta1 = 92.252, 差值= 13.9207
# 第213次 ：theta0 = 423.584, theta1 = 92.277, 差值= 13.3695
# 第214次 ：theta0 = 423.695, theta1 = 92.301, 差值= 12.8400
# 第215次 ：theta0 = 423.804, theta1 = 92.324, 差值= 12.3316
# 第216次 ：theta0 = 423.911, theta1 = 92.347, 差值= 11.8433
# 第217次 ：theta0 = 424.016, theta1 = 92.370, 差值= 11.3743
# 第218次 ：theta0 = 424.119, theta1 = 92.392, 差值= 10.9238
# 第219次 ：theta0 = 424.219, theta1 = 92.414, 差值= 10.4913
# 第220次 ：theta0 = 424.318, theta1 = 92.435, 差值= 10.0758
# 第221次 ：theta0 = 424.415, theta1 = 92.456, 差值= 9.6768
# 第222次 ：theta0 = 424.509, theta1 = 92.477, 差值= 9.2936
# 第223次 ：theta0 = 424.602, theta1 = 92.497, 差值= 8.9256
# 第224次 ：theta0 = 424.693, theta1 = 92.516, 差值= 8.5721
# 第225次 ：theta0 = 424.782, theta1 = 92.536, 差值= 8.2327
# 第226次 ：theta0 = 424.870, theta1 = 92.554, 差值= 7.9066
# 第227次 ：theta0 = 424.955, theta1 = 92.573, 差值= 7.5935
# 第228次 ：theta0 = 425.039, theta1 = 92.591, 差值= 7.2928
# 第229次 ：theta0 = 425.121, theta1 = 92.609, 差值= 7.0040
# 第230次 ：theta0 = 425.202, theta1 = 92.626, 差值= 6.7267
# 第231次 ：theta0 = 425.281, theta1 = 92.643, 差值= 6.4603
# 第232次 ：theta0 = 425.358, theta1 = 92.660, 差值= 6.2045
# 第233次 ：theta0 = 425.434, theta1 = 92.676, 差值= 5.9588
# 第234次 ：theta0 = 425.508, theta1 = 92.692, 差值= 5.7228
# 第235次 ：theta0 = 425.581, theta1 = 92.708, 差值= 5.4962
# 第236次 ：theta0 = 425.653, theta1 = 92.723, 差值= 5.2785
# 第237次 ：theta0 = 425.723, theta1 = 92.739, 差值= 5.0695
# 第238次 ：theta0 = 425.791, theta1 = 92.753, 差值= 4.8688
# 第239次 ：theta0 = 425.858, theta1 = 92.768, 差值= 4.6760
# 第240次 ：theta0 = 425.924, theta1 = 92.782, 差值= 4.4908
# 第241次 ：theta0 = 425.989, theta1 = 92.796, 差值= 4.3130
# 第242次 ：theta0 = 426.052, theta1 = 92.810, 差值= 4.1422
# 第243次 ：theta0 = 426.114, theta1 = 92.823, 差值= 3.9781
# 第244次 ：theta0 = 426.175, theta1 = 92.836, 差值= 3.8206
# 第245次 ：theta0 = 426.234, theta1 = 92.849, 差值= 3.6693
# 第246次 ：theta0 = 426.292, theta1 = 92.862, 差值= 3.5240
# 第247次 ：theta0 = 426.350, theta1 = 92.874, 差值= 3.3844
# 第248次 ：theta0 = 426.406, theta1 = 92.886, 差值= 3.2504
# 第249次 ：theta0 = 426.460, theta1 = 92.898, 差值= 3.1217
# 第250次 ：theta0 = 426.514, theta1 = 92.910, 差值= 2.9981
# 第251次 ：theta0 = 426.567, theta1 = 92.921, 差值= 2.8794
# 第252次 ：theta0 = 426.619, theta1 = 92.932, 差值= 2.7653
# 第253次 ：theta0 = 426.669, theta1 = 92.943, 差值= 2.6558
# 第254次 ：theta0 = 426.719, theta1 = 92.954, 差值= 2.5507
# 第255次 ：theta0 = 426.768, theta1 = 92.964, 差值= 2.4497
# 第256次 ：theta0 = 426.815, theta1 = 92.975, 差值= 2.3526
# 第257次 ：theta0 = 426.862, theta1 = 92.985, 差值= 2.2595
# 第258次 ：theta0 = 426.908, theta1 = 92.995, 差值= 2.1700
# 第259次 ：theta0 = 426.952, theta1 = 93.004, 差值= 2.0841
# 第260次 ：theta0 = 426.996, theta1 = 93.014, 差值= 2.0015
# 第261次 ：theta0 = 427.039, theta1 = 93.023, 差值= 1.9223
# 第262次 ：theta0 = 427.082, theta1 = 93.032, 差值= 1.8462
# 第263次 ：theta0 = 427.123, theta1 = 93.041, 差值= 1.7731
# 第264次 ：theta0 = 427.164, theta1 = 93.050, 差值= 1.7028
# 第265次 ：theta0 = 427.203, theta1 = 93.058, 差值= 1.6354
# 第266次 ：theta0 = 427.242, theta1 = 93.067, 差值= 1.5706
# 第267次 ：theta0 = 427.280, theta1 = 93.075, 差值= 1.5084
# 第268次 ：theta0 = 427.318, theta1 = 93.083, 差值= 1.4487
# 第269次 ：theta0 = 427.354, theta1 = 93.091, 差值= 1.3913
# 第270次 ：theta0 = 427.390, theta1 = 93.099, 差值= 1.3362
# 第271次 ：theta0 = 427.426, theta1 = 93.106, 差值= 1.2833
# 第272次 ：theta0 = 427.460, theta1 = 93.114, 差值= 1.2325
# 第273次 ：theta0 = 427.494, theta1 = 93.121, 差值= 1.1837
# 第274次 ：theta0 = 427.527, theta1 = 93.128, 差值= 1.1368
# 第275次 ：theta0 = 427.559, theta1 = 93.135, 差值= 1.0918
# 第276次 ：theta0 = 427.591, theta1 = 93.142, 差值= 1.0486
# 第277次 ：theta0 = 427.622, theta1 = 93.149, 差值= 1.0071
# 第278次 ：theta0 = 427.653, theta1 = 93.155, 差值= 0.9672
# 第279次 ：theta0 = 427.683, theta1 = 93.162, 差值= 0.9289
# 第280次 ：theta0 = 427.712, theta1 = 93.168, 差值= 0.8921
# 第281次 ：theta0 = 427.741, theta1 = 93.174, 差值= 0.8568
# 第282次 ：theta0 = 427.769, theta1 = 93.181, 差值= 0.8228
# 第283次 ：theta0 = 427.797, theta1 = 93.187, 差值= 0.7903
# 第284次 ：theta0 = 427.824, theta1 = 93.192, 差值= 0.7590
# 第285次 ：theta0 = 427.850, theta1 = 93.198, 差值= 0.7289
# 第286次 ：theta0 = 427.876, theta1 = 93.204, 差值= 0.7000
# 第287次 ：theta0 = 427.902, theta1 = 93.209, 差值= 0.6723
# 第288次 ：theta0 = 427.927, theta1 = 93.215, 差值= 0.6457
# 第289次 ：theta0 = 427.951, theta1 = 93.220, 差值= 0.6201
# 第290次 ：theta0 = 427.975, theta1 = 93.225, 差值= 0.5956
# 第291次 ：theta0 = 427.999, theta1 = 93.230, 差值= 0.5720
# 第292次 ：theta0 = 428.022, theta1 = 93.235, 差值= 0.5493
# 第293次 ：theta0 = 428.044, theta1 = 93.240, 差值= 0.5276
# 第294次 ：theta0 = 428.066, theta1 = 93.245, 差值= 0.5067
# 第295次 ：theta0 = 428.088, theta1 = 93.249, 差值= 0.4866
# 第296次 ：theta0 = 428.109, theta1 = 93.254, 差值= 0.4674
# 第297次 ：theta0 = 428.130, theta1 = 93.259, 差值= 0.4488
# 第298次 ：theta0 = 428.151, theta1 = 93.263, 差值= 0.4311
# 第299次 ：theta0 = 428.171, theta1 = 93.267, 差值= 0.4140
# 第300次 ：theta0 = 428.190, theta1 = 93.271, 差值= 0.3976
# 第301次 ：theta0 = 428.209, theta1 = 93.276, 差值= 0.3819
# 第302次 ：theta0 = 428.228, theta1 = 93.280, 差值= 0.3667
# 第303次 ：theta0 = 428.247, theta1 = 93.284, 差值= 0.3522
# 第304次 ：theta0 = 428.265, theta1 = 93.288, 差值= 0.3383
# 第305次 ：theta0 = 428.282, theta1 = 93.291, 差值= 0.3249
# 第306次 ：theta0 = 428.300, theta1 = 93.295, 差值= 0.3120
# 第307次 ：theta0 = 428.317, theta1 = 93.299, 差值= 0.2997
# 第308次 ：theta0 = 428.333, theta1 = 93.302, 差值= 0.2878
# 第309次 ：theta0 = 428.350, theta1 = 93.306, 差值= 0.2764
# 第310次 ：theta0 = 428.366, theta1 = 93.309, 差值= 0.2654
# 第311次 ：theta0 = 428.381, theta1 = 93.313, 差值= 0.2549
# 第312次 ：theta0 = 428.397, theta1 = 93.316, 差值= 0.2448
# 第313次 ：theta0 = 428.412, theta1 = 93.319, 差值= 0.2351
# 第314次 ：theta0 = 428.427, theta1 = 93.323, 差值= 0.2258
# 第315次 ：theta0 = 428.441, theta1 = 93.326, 差值= 0.2169
# 第316次 ：theta0 = 428.455, theta1 = 93.329, 差值= 0.2083
# 第317次 ：theta0 = 428.469, theta1 = 93.332, 差值= 0.2000
# 第318次 ：theta0 = 428.483, theta1 = 93.335, 差值= 0.1921
# 第319次 ：theta0 = 428.496, theta1 = 93.338, 差值= 0.1845
# 第320次 ：theta0 = 428.509, theta1 = 93.340, 差值= 0.1772
# 第321次 ：theta0 = 428.522, theta1 = 93.343, 差值= 0.1702
# 第322次 ：theta0 = 428.535, theta1 = 93.346, 差值= 0.1635
# 第323次 ：theta0 = 428.547, theta1 = 93.349, 差值= 0.1570
# 第324次 ：theta0 = 428.559, theta1 = 93.351, 差值= 0.1508
# 第325次 ：theta0 = 428.571, theta1 = 93.354, 差值= 0.1448
# 第326次 ：theta0 = 428.582, theta1 = 93.356, 差值= 0.1391
# 第327次 ：theta0 = 428.594, theta1 = 93.359, 差值= 0.1336
# 第328次 ：theta0 = 428.605, theta1 = 93.361, 差值= 0.1283
# 第329次 ：theta0 = 428.616, theta1 = 93.363, 差值= 0.1232
# 第330次 ：theta0 = 428.626, theta1 = 93.366, 差值= 0.1183
# 第331次 ：theta0 = 428.637, theta1 = 93.368, 差值= 0.1136
# 第332次 ：theta0 = 428.647, theta1 = 93.370, 差值= 0.1091
# 第333次 ：theta0 = 428.657, theta1 = 93.372, 差值= 0.1048
# 第334次 ：theta0 = 428.667, theta1 = 93.374, 差值= 0.1007
# 第335次 ：theta0 = 428.677, theta1 = 93.377, 差值= 0.0967
# 第336次 ：theta0 = 428.686, theta1 = 93.379, 差值= 0.0928
# 第337次 ：theta0 = 428.695, theta1 = 93.381, 差值= 0.0892
# 第338次 ：theta0 = 428.705, theta1 = 93.383, 差值= 0.0856
# 第339次 ：theta0 = 428.713, theta1 = 93.384, 差值= 0.0822
# 第340次 ：theta0 = 428.722, theta1 = 93.386, 差值= 0.0790
# 第341次 ：theta0 = 428.731, theta1 = 93.388, 差值= 0.0759
# 第342次 ：theta0 = 428.739, theta1 = 93.390, 差值= 0.0729
# 第343次 ：theta0 = 428.747, theta1 = 93.392, 差值= 0.0700
# 第344次 ：theta0 = 428.755, theta1 = 93.394, 差值= 0.0672
# 第345次 ：theta0 = 428.763, theta1 = 93.395, 差值= 0.0645
# 第346次 ：theta0 = 428.771, theta1 = 93.397, 差值= 0.0620
# 第347次 ：theta0 = 428.779, theta1 = 93.399, 差值= 0.0595
# 第348次 ：theta0 = 428.786, theta1 = 93.400, 差值= 0.0572
# 第349次 ：theta0 = 428.793, theta1 = 93.402, 差值= 0.0549
# 第350次 ：theta0 = 428.800, theta1 = 93.403, 差值= 0.0527
# 第351次 ：theta0 = 428.807, theta1 = 93.405, 差值= 0.0506
# 第352次 ：theta0 = 428.814, theta1 = 93.406, 差值= 0.0486
# 第353次 ：theta0 = 428.821, theta1 = 93.408, 差值= 0.0467
# 第354次 ：theta0 = 428.828, theta1 = 93.409, 差值= 0.0449
# 第355次 ：theta0 = 428.834, theta1 = 93.411, 差值= 0.0431
# 第356次 ：theta0 = 428.840, theta1 = 93.412, 差值= 0.0414
# 第357次 ：theta0 = 428.847, theta1 = 93.413, 差值= 0.0397
# 第358次 ：theta0 = 428.853, theta1 = 93.415, 差值= 0.0382
# 第359次 ：theta0 = 428.859, theta1 = 93.416, 差值= 0.0367
# 第360次 ：theta0 = 428.864, theta1 = 93.417, 差值= 0.0352
# 第361次 ：theta0 = 428.870, theta1 = 93.418, 差值= 0.0338
# 第362次 ：theta0 = 428.876, theta1 = 93.420, 差值= 0.0325
# 第363次 ：theta0 = 428.881, theta1 = 93.421, 差值= 0.0312
# 第364次 ：theta0 = 428.887, theta1 = 93.422, 差值= 0.0299
# 第365次 ：theta0 = 428.892, theta1 = 93.423, 差值= 0.0288
# 第366次 ：theta0 = 428.897, theta1 = 93.424, 差值= 0.0276
# 第367次 ：theta0 = 428.902, theta1 = 93.425, 差值= 0.0265
# 第368次 ：theta0 = 428.907, theta1 = 93.426, 差值= 0.0255
# 第369次 ：theta0 = 428.912, theta1 = 93.427, 差值= 0.0245
# 第370次 ：theta0 = 428.917, theta1 = 93.428, 差值= 0.0235
# 第371次 ：theta0 = 428.921, theta1 = 93.429, 差值= 0.0226
# 第372次 ：theta0 = 428.926, theta1 = 93.430, 差值= 0.0217
# 第373次 ：theta0 = 428.930, theta1 = 93.431, 差值= 0.0208
# 第374次 ：theta0 = 428.935, theta1 = 93.432, 差值= 0.0200
# 第375次 ：theta0 = 428.939, theta1 = 93.433, 差值= 0.0192
# 第376次 ：theta0 = 428.943, theta1 = 93.434, 差值= 0.0184
# 第377次 ：theta0 = 428.947, theta1 = 93.435, 差值= 0.0177
# 第378次 ：theta0 = 428.951, theta1 = 93.436, 差值= 0.0170
# 第379次 ：theta0 = 428.955, theta1 = 93.437, 差值= 0.0163
# 第380次 ：theta0 = 428.959, theta1 = 93.438, 差值= 0.0157
# 第381次 ：theta0 = 428.963, theta1 = 93.438, 差值= 0.0151
# 第382次 ：theta0 = 428.967, theta1 = 93.439, 差值= 0.0145
# 第383次 ：theta0 = 428.971, theta1 = 93.440, 差值= 0.0139
# 第384次 ：theta0 = 428.974, theta1 = 93.441, 差值= 0.0133
# 第385次 ：theta0 = 428.978, theta1 = 93.442, 差值= 0.0128
# 第386次 ：theta0 = 428.981, theta1 = 93.442, 差值= 0.0123
# 第387次 ：theta0 = 428.984, theta1 = 93.443, 差值= 0.0118
# 第388次 ：theta0 = 428.988, theta1 = 93.444, 差值= 0.0114
# 第389次 ：theta0 = 428.991, theta1 = 93.444, 差值= 0.0109
# 第390次 ：theta0 = 428.994, theta1 = 93.445, 差值= 0.0105
# 第391次 ：theta0 = 428.997, theta1 = 93.446, 差值= 0.0101
# 第392次 ：theta0 = 429.000, theta1 = 93.446, 差值= 0.0097

# %%
x = np.linspace(-3, 3, 100)

# %%
plt.plot(train_z, train_y, 'o')
plt.plot(x,f(x))

# %%
f(standardize(100))
# Out:
# 370.96721868761085

# %%
f(standardize(200))
# Out:
# 510.4699977001121

# %%
f(standardize(300))
# Out:
# 649.9727767126134
